# %%
#非自創
#來源:https://github.com/iiapache/DecisionTree
from id3 import id3,draw_tree

# %%
dt=id3("baseball.csv")
draw_tree(dt)
# Out:
# desicionTree:
#  {'Outlook': {'Overcast': 'Yes', 'Sunny': {'Humidity': {'Normal': 'Yes', 'High': 'No'}}, 'Rain': {'Wind': {'Weak': 'Yes', 'Strong': 'No'}}}}
