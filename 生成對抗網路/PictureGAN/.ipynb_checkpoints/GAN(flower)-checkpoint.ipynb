# %%
from __future__ import division, print_function, absolute_import

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("flowers", one_hot=True)

# Training Params
num_steps = 100000
batch_size = 128
learning_rate = 0.0002

# Network Params
image_dim = 784 # 28*28 pixels
gen_hidden_dim = 256
disc_hidden_dim = 256
noise_dim = 100 # Noise data points

# A custom initialization (see Xavier Glorot init)
def glorot_init(shape):
    return tf.random_normal(shape=shape, stddev=1. / tf.sqrt(shape[0] / 2.))

# Store layers weight & bias
weights = {
    'gen_hidden1': tf.Variable(glorot_init([noise_dim, gen_hidden_dim])),
    'gen_out': tf.Variable(glorot_init([gen_hidden_dim, image_dim])),
    'disc_hidden1': tf.Variable(glorot_init([image_dim, disc_hidden_dim])),
    'disc_out': tf.Variable(glorot_init([disc_hidden_dim, 1])),
}
biases = {
    'gen_hidden1': tf.Variable(tf.zeros([gen_hidden_dim])),
    'gen_out': tf.Variable(tf.zeros([image_dim])),
    'disc_hidden1': tf.Variable(tf.zeros([disc_hidden_dim])),
    'disc_out': tf.Variable(tf.zeros([1])),
}


# Generator
def generator(x):
    hidden_layer = tf.matmul(x, weights['gen_hidden1'])
    hidden_layer = tf.add(hidden_layer, biases['gen_hidden1'])
    hidden_layer = tf.nn.relu(hidden_layer)
    out_layer = tf.matmul(hidden_layer, weights['gen_out'])
    out_layer = tf.add(out_layer, biases['gen_out'])
    out_layer = tf.nn.sigmoid(out_layer)
    return out_layer


# Discriminator
def discriminator(x):
    hidden_layer = tf.matmul(x, weights['disc_hidden1'])
    hidden_layer = tf.add(hidden_layer, biases['disc_hidden1'])
    hidden_layer = tf.nn.relu(hidden_layer)
    out_layer = tf.matmul(hidden_layer, weights['disc_out'])
    out_layer = tf.add(out_layer, biases['disc_out'])
    out_layer = tf.nn.sigmoid(out_layer)
    return out_layer

# Build Networks
# Network Inputs
gen_input = tf.placeholder(tf.float32, shape=[None, noise_dim], name='input_noise')
disc_input = tf.placeholder(tf.float32, shape=[None, image_dim], name='disc_input')

# Build Generator Network
gen_sample = generator(gen_input)

# Build 2 Discriminator Networks (one from noise input, one from generated samples)
disc_real = discriminator(disc_input)
disc_fake = discriminator(gen_sample)

# Build Loss
gen_loss = -tf.reduce_mean(tf.log(disc_fake))
disc_loss = -tf.reduce_mean(tf.log(disc_real) + tf.log(1. - disc_fake))

# Build Optimizers
optimizer_gen = tf.train.AdamOptimizer(learning_rate=learning_rate)
optimizer_disc = tf.train.AdamOptimizer(learning_rate=learning_rate)

# Generator Network Variables
gen_vars = [weights['gen_hidden1'], weights['gen_out'],
            biases['gen_hidden1'], biases['gen_out']]
# Discriminator Network Variables
disc_vars = [weights['disc_hidden1'], weights['disc_out'],
            biases['disc_hidden1'], biases['disc_out']]

# Create training operations
train_gen = optimizer_gen.minimize(gen_loss, var_list=gen_vars)
train_disc = optimizer_disc.minimize(disc_loss, var_list=disc_vars)

# Initialize the variables (i.e. assign their default value)
init = tf.global_variables_initializer()

# Start training
with tf.Session() as sess:

    # Run the initializer
    sess.run(init)

    for i in range(1, num_steps+1):
        # Prepare Data
        # Get the next batch of MNIST data (only images are needed, not labels)
        batch_x, _ = mnist.train.next_batch(batch_size)
        # Generate noise to feed to the generator
        z = np.random.uniform(-1., 1., size=[batch_size, noise_dim])

        # Train
        feed_dict = {disc_input: batch_x, gen_input: z}
        _, _, gl, dl = sess.run([train_gen, train_disc, gen_loss, disc_loss],
                                feed_dict=feed_dict)
        if i % 1000 == 0 or i == 1:
            print('Step %i: Generator Loss: %f, Discriminator Loss: %f' % (i, gl, dl))

    # Generate images from noise, using the generator network.
    f, a = plt.subplots(4, 10, figsize=(10, 4))
    for i in range(10):
        # Noise input.
        z = np.random.uniform(-1., 1., size=[4, noise_dim])
        g = sess.run([gen_sample], feed_dict={gen_input: z})
        g = np.reshape(g, newshape=(4, 28, 28, 1))
        # Reverse colours for better display
        g = -1 * (g - 1)
        for j in range(4):
            # Generate image from noise. Extend to 3 channels for matplot figure.
            img = np.reshape(np.repeat(g[j][:, :, np.newaxis], 3, axis=2),
                             newshape=(28, 28, 3))
            a[j][i].imshow(img)

    f.show()
    plt.draw()
    plt.waitforbuttonpress()
# Out:
# WARNING:tensorflow:From C:\Users\lamon\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting flowers\train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting flowers\train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting flowers\t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting flowers\t10k-labels-idx1-ubyte.gz
# Step 1: Generator Loss: 0.271981, Discriminator Loss: 2.053693
# Step 1000: Generator Loss: 3.785904, Discriminator Loss: 0.053786
# Step 2000: Generator Loss: 4.380555, Discriminator Loss: 0.032576
# Step 3000: Generator Loss: 5.496267, Discriminator Loss: 0.014302
# Step 4000: Generator Loss: 4.078100, Discriminator Loss: 0.051576
# Step 5000: Generator Loss: 4.578384, Discriminator Loss: 0.077146
# Step 6000: Generator Loss: 3.558665, Discriminator Loss: 0.222298
# Step 7000: Generator Loss: 4.142086, Discriminator Loss: 0.097738
# Step 8000: Generator Loss: 4.229319, Discriminator Loss: 0.104747
# Step 9000: Generator Loss: 3.793233, Discriminator Loss: 0.274991
# Step 10000: Generator Loss: 3.941920, Discriminator Loss: 0.118789
# Step 11000: Generator Loss: 3.512969, Discriminator Loss: 0.201448
# Step 12000: Generator Loss: 3.787793, Discriminator Loss: 0.249936
# Step 13000: Generator Loss: 3.448083, Discriminator Loss: 0.167625
# Step 14000: Generator Loss: 3.547929, Discriminator Loss: 0.361602
# Step 15000: Generator Loss: 3.140514, Discriminator Loss: 0.337237
# Step 16000: Generator Loss: 3.552053, Discriminator Loss: 0.305699
# Step 17000: Generator Loss: 3.246432, Discriminator Loss: 0.334926
# Step 18000: Generator Loss: 3.058856, Discriminator Loss: 0.462157
# Step 19000: Generator Loss: 3.750633, Discriminator Loss: 0.253042
# Step 20000: Generator Loss: 3.355626, Discriminator Loss: 0.280334
# Step 21000: Generator Loss: 4.086422, Discriminator Loss: 0.267867
# Step 22000: Generator Loss: 3.295457, Discriminator Loss: 0.275373
# Step 23000: Generator Loss: 3.744059, Discriminator Loss: 0.283626
# Step 24000: Generator Loss: 4.620839, Discriminator Loss: 0.154416
# Step 25000: Generator Loss: 3.489087, Discriminator Loss: 0.236188
# Step 26000: Generator Loss: 3.754999, Discriminator Loss: 0.405236
# Step 27000: Generator Loss: 3.366005, Discriminator Loss: 0.359930
# Step 28000: Generator Loss: 3.464776, Discriminator Loss: 0.287439
# Step 29000: Generator Loss: 3.533378, Discriminator Loss: 0.311597
# Step 30000: Generator Loss: 2.993236, Discriminator Loss: 0.337795
# Step 31000: Generator Loss: 3.054934, Discriminator Loss: 0.352172
# Step 32000: Generator Loss: 3.454516, Discriminator Loss: 0.447159
# Step 33000: Generator Loss: 3.055464, Discriminator Loss: 0.400925
# Step 34000: Generator Loss: 3.159248, Discriminator Loss: 0.362606
# Step 35000: Generator Loss: 3.345946, Discriminator Loss: 0.391515
# Step 36000: Generator Loss: 3.060582, Discriminator Loss: 0.501694
# Step 37000: Generator Loss: 2.801406, Discriminator Loss: 0.497150
# Step 38000: Generator Loss: 2.620274, Discriminator Loss: 0.527842
# Step 39000: Generator Loss: 3.077857, Discriminator Loss: 0.530382
# Step 40000: Generator Loss: 3.010214, Discriminator Loss: 0.477324
# Step 41000: Generator Loss: 3.284857, Discriminator Loss: 0.288481
# Step 42000: Generator Loss: 3.283275, Discriminator Loss: 0.417157
# Step 43000: Generator Loss: 2.681970, Discriminator Loss: 0.487705
# Step 44000: Generator Loss: 2.882285, Discriminator Loss: 0.483146
# Step 45000: Generator Loss: 2.681174, Discriminator Loss: 0.502561
# Step 46000: Generator Loss: 2.655249, Discriminator Loss: 0.492534
# Step 47000: Generator Loss: 2.911136, Discriminator Loss: 0.451584
# Step 48000: Generator Loss: 2.656996, Discriminator Loss: 0.574687
# Step 49000: Generator Loss: 2.934589, Discriminator Loss: 0.458467
# Step 50000: Generator Loss: 3.122830, Discriminator Loss: 0.460804
# Step 51000: Generator Loss: 2.698471, Discriminator Loss: 0.587640
# Step 52000: Generator Loss: 3.210999, Discriminator Loss: 0.457706
# Step 53000: Generator Loss: 3.006498, Discriminator Loss: 0.382199
# Step 54000: Generator Loss: 3.197370, Discriminator Loss: 0.419265
# Step 55000: Generator Loss: 2.998868, Discriminator Loss: 0.300190
# Step 56000: Generator Loss: 2.752406, Discriminator Loss: 0.349921
# Step 57000: Generator Loss: 2.786501, Discriminator Loss: 0.463303
# Step 58000: Generator Loss: 3.072246, Discriminator Loss: 0.377976
# Step 59000: Generator Loss: 2.736752, Discriminator Loss: 0.474340
# Step 60000: Generator Loss: 2.787831, Discriminator Loss: 0.462483
# Step 61000: Generator Loss: 3.142687, Discriminator Loss: 0.476366
# Step 62000: Generator Loss: 2.676956, Discriminator Loss: 0.502417
# Step 63000: Generator Loss: 3.530870, Discriminator Loss: 0.497889
# Step 64000: Generator Loss: 2.934223, Discriminator Loss: 0.466078
# Step 65000: Generator Loss: 3.138028, Discriminator Loss: 0.349175
# Step 66000: Generator Loss: 2.759861, Discriminator Loss: 0.347751
# Step 67000: Generator Loss: 3.044500, Discriminator Loss: 0.466595
# Step 68000: Generator Loss: 2.792368, Discriminator Loss: 0.420974
# Step 69000: Generator Loss: 3.188879, Discriminator Loss: 0.365206
# Step 70000: Generator Loss: 2.792073, Discriminator Loss: 0.421256
# Step 71000: Generator Loss: 2.838328, Discriminator Loss: 0.425500
# Step 72000: Generator Loss: 2.749900, Discriminator Loss: 0.376831
# Step 73000: Generator Loss: 2.786687, Discriminator Loss: 0.458719
# Step 74000: Generator Loss: 3.592049, Discriminator Loss: 0.309290
# Step 75000: Generator Loss: 2.742840, Discriminator Loss: 0.405553
# Step 76000: Generator Loss: 2.887274, Discriminator Loss: 0.442498
# Step 77000: Generator Loss: 2.599412, Discriminator Loss: 0.418221
# Step 78000: Generator Loss: 3.039010, Discriminator Loss: 0.464955
# Step 79000: Generator Loss: 2.560962, Discriminator Loss: 0.478776
# Step 80000: Generator Loss: 3.096282, Discriminator Loss: 0.422388
# Step 81000: Generator Loss: 2.805707, Discriminator Loss: 0.404842
# Step 82000: Generator Loss: nan, Discriminator Loss: nan
# Step 83000: Generator Loss: nan, Discriminator Loss: nan
# Step 84000: Generator Loss: nan, Discriminator Loss: nan
# Step 85000: Generator Loss: nan, Discriminator Loss: nan
# Step 86000: Generator Loss: nan, Discriminator Loss: nan
# Step 87000: Generator Loss: nan, Discriminator Loss: nan
# Step 88000: Generator Loss: nan, Discriminator Loss: nan
# Step 89000: Generator Loss: nan, Discriminator Loss: nan
# Step 90000: Generator Loss: nan, Discriminator Loss: nan
# Step 91000: Generator Loss: nan, Discriminator Loss: nan
# Step 92000: Generator Loss: nan, Discriminator Loss: nan
# Step 93000: Generator Loss: nan, Discriminator Loss: nan
# Step 94000: Generator Loss: nan, Discriminator Loss: nan
# Step 95000: Generator Loss: nan, Discriminator Loss: nan
# Step 96000: Generator Loss: nan, Discriminator Loss: nan
# Step 97000: Generator Loss: nan, Discriminator Loss: nan
# Step 98000: Generator Loss: nan, Discriminator Loss: nan
# Step 99000: Generator Loss: nan, Discriminator Loss: nan
# Step 100000: Generator Loss: nan, Discriminator Loss: nan
# C:\Users\lamon\Anaconda3\lib\site-packages\ipykernel_launcher.py:134: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# C:\Users\lamon\Anaconda3\lib\site-packages\ipykernel_launcher.py:136: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
