# %%
import pic
#WARNING def appraisal()需使用DNN計算 請勿重複

# %%
test = pic.pic_appraisal("D:\\個人資料夾\\CG收集\\A\\0hLJBlM - Imgur.jpg")

# %%
test.analysis("show")
# Out:
# 與原圖差距: 274.41729736328125
# 真實差距: 5032979.999999868
# 平均差: 389.97210599720034
# 色塊數 777
# 平均色塊: 0.0602045560204556

# %%
test.analysis("return")
# Out:
# (348.36920812025414,
#  5032979.999999868,
#  389.97210599720034,
#  777,
#  0.0602045560204556)

# %%
test.appraisal()
# Out:
# 'A'

# %%
import pic

# %%
test = pic.pic_appraisal("D:\\個人資料夾\\CG收集\\test")

# %%
test.analysis("show")
# Out:
# 與原圖差距: 274.41729736328125
# 真實差距: 5032979.999999868
# 平均差: 389.97210599720034
# 色塊數 777
# 平均色塊: 0.0602045560204556
# 與原圖差距: 244.7227783203125
# 真實差距: 4366281.999999977
# 平均差: 352.57445090439086
# 色塊數 1029
# 平均色塊: 0.08309108527131782

# %%
test.analysis("return")
# Out:
# [(348.36920812025414,
#   5032979.999999868,
#   389.97210599720034,
#   777,
#   0.0602045560204556),
#  (323.7676033591731,
#   4366281.999999977,
#   352.57445090439086,
#   1029,
#   0.08309108527131782)]

# %%
test.appraisal()
# Out:
# array(['A', 'A'], dtype='<U1')
